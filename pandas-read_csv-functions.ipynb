# %% [markdown]
# ## Pandas - wczytywanie danych / tworzenie obiektów DataFrame
#
# #### Autor: Marian Witkowski marian.witkowski[at]gmail.com
#
# #### Niniejszy materiał może być używany w celach dydaktyczych pod warunkem poinformowania o autorze.
#
# Przykład użycia najczęstszych opcji w metodzie pd.read_csv() w Pandas:
# - ładowanie danych z CSV
# - ładowanie danych z CSV bez wiersza nagłówkego
# - ładowanie wybranych kolumn
# - ładowanie danych z określaniem indeksu
# - pobierania zadanej liczby wierszy, pomijanie wierszy początkowych i/lub końcowych
# - interpretacja danych jako NaN
# - ładowanie danych z określaniem typów dla kolumn
# - ładowanie danych z przetwarzaniem kolumn
# - ładowanie skompresowanych plików
# - ładowanie danych w porcjach
#
# <img src='http://51.91.120.89/itm/p.png' border=0 />

# %%
import datetime
import numpy as np
import pandas as pd
import warnings

warnings.filterwarnings("ignore")

# %% [markdown]
# ### Ładowanie danych z pliku CSV

# %%
url = "https://raw.githubusercontent.com/marianwitkowski/bs-datasets/main/f500.csv"
df = pd.read_csv(url, sep=",")
df.head()
# Out:
#                     company  rank  revenues  revenue_change  profits  assets  \
# 0                   Walmart     1    485873             0.8  13643.0  198825
# 1                State Grid     2    315199            -4.4   9571.3  489838
# 2             Sinopec Group     3    267518            -9.1   1257.9  310726
# 3  China National Petroleum     4    262573           -12.3   1867.5  585619
# 4              Toyota Motor     5    254694             7.7  16899.3  437575
#
#    profit_change                  ceo                  industry  \
# 0           -7.2  C. Douglas McMillon     General Merchandisers
# 1           -6.2              Kou Wei                 Utilities
# 2          -65.0            Wang Yupu        Petroleum Refining
# 3          -73.7        Zhang Jianhua        Petroleum Refining
# 4          -12.3          Akio Toyoda  Motor Vehicles and Parts
#
#                    sector  previous_rank country      hq_location  \
# 0               Retailing              1     USA  Bentonville, AR
# 1                  Energy              2   China   Beijing, China
# 2                  Energy              4   China   Beijing, China
# 3                  Energy              3   China   Beijing, China
# 4  Motor Vehicles & Parts              8   Japan    Toyota, Japan
#
#                         website  years_on_global_500_list  employees  \
# 0        http://www.walmart.com                        23    2300000
# 1        http://www.sgcc.com.cn                        17     926067
# 2        http://www.sinopec.com                        19     713288
# 3        http://www.cnpc.com.cn                        17    1512048
# 4  http://www.toyota-global.com                        23     364445
#
#    total_stockholder_equity
# 0                     77798
# 1                    209456
# 2                    106523
# 3                    301893
# 4                    157210

# %% [markdown]
# ### Ładowanie danych z pliku CSV bez wiersza z nazwami kolumn

# %%
url = "https://raw.githubusercontent.com/marianwitkowski/bs-datasets/main/f500nh.csv"
df = pd.read_csv(url, sep=",", header=None)
df.head()
# Out:
#                          0   1       2     3        4       5     6   \
# 0                   Walmart   1  485873   0.8  13643.0  198825  -7.2
# 1                State Grid   2  315199  -4.4   9571.3  489838  -6.2
# 2             Sinopec Group   3  267518  -9.1   1257.9  310726 -65.0
# 3  China National Petroleum   4  262573 -12.3   1867.5  585619 -73.7
# 4              Toyota Motor   5  254694   7.7  16899.3  437575 -12.3
#
#                     7                         8                       9   10  \
# 0  C. Douglas McMillon     General Merchandisers               Retailing   1
# 1              Kou Wei                 Utilities                  Energy   2
# 2            Wang Yupu        Petroleum Refining                  Energy   4
# 3        Zhang Jianhua        Petroleum Refining                  Energy   3
# 4          Akio Toyoda  Motor Vehicles and Parts  Motor Vehicles & Parts   8
#
#       11               12                            13  14       15      16
# 0    USA  Bentonville, AR        http://www.walmart.com  23  2300000   77798
# 1  China   Beijing, China        http://www.sgcc.com.cn  17   926067  209456
# 2  China   Beijing, China        http://www.sinopec.com  19   713288  106523
# 3  China   Beijing, China        http://www.cnpc.com.cn  17  1512048  301893
# 4  Japan    Toyota, Japan  http://www.toyota-global.com  23   364445  157210

# %% [markdown]
# ### Ładowanie danych z pliku CSV bez wiersza z nazwami kolumn, przypisanie kolumn

# %%
columns = ['company', 'rank', 'revenues', 'revenue_change', 'profits', 'assets',
       'profit_change', 'ceo', 'industry', 'sector', 'previous_rank',
       'country', 'hq_location', 'website', 'years_on_global_500_list',
       'employees', 'total_stockholder_equity']
url = "https://raw.githubusercontent.com/marianwitkowski/bs-datasets/main/f500nh.csv"
df = pd.read_csv(url, sep=",", header=None, names=columns)
df.head()
# Out:
#                     company  rank  revenues  revenue_change  profits  assets  \
# 0                   Walmart     1    485873             0.8  13643.0  198825
# 1                State Grid     2    315199            -4.4   9571.3  489838
# 2             Sinopec Group     3    267518            -9.1   1257.9  310726
# 3  China National Petroleum     4    262573           -12.3   1867.5  585619
# 4              Toyota Motor     5    254694             7.7  16899.3  437575
#
#    profit_change                  ceo                  industry  \
# 0           -7.2  C. Douglas McMillon     General Merchandisers
# 1           -6.2              Kou Wei                 Utilities
# 2          -65.0            Wang Yupu        Petroleum Refining
# 3          -73.7        Zhang Jianhua        Petroleum Refining
# 4          -12.3          Akio Toyoda  Motor Vehicles and Parts
#
#                    sector  previous_rank country      hq_location  \
# 0               Retailing              1     USA  Bentonville, AR
# 1                  Energy              2   China   Beijing, China
# 2                  Energy              4   China   Beijing, China
# 3                  Energy              3   China   Beijing, China
# 4  Motor Vehicles & Parts              8   Japan    Toyota, Japan
#
#                         website  years_on_global_500_list  employees  \
# 0        http://www.walmart.com                        23    2300000
# 1        http://www.sgcc.com.cn                        17     926067
# 2        http://www.sinopec.com                        19     713288
# 3        http://www.cnpc.com.cn                        17    1512048
# 4  http://www.toyota-global.com                        23     364445
#
#    total_stockholder_equity
# 0                     77798
# 1                    209456
# 2                    106523
# 3                    301893
# 4                    157210

# %% [markdown]
# ### Ładowanie wybranych kolumn z pliku CSV

# %%
url = "https://raw.githubusercontent.com/marianwitkowski/bs-datasets/main/f500.csv"
df = pd.read_csv(url, sep=",", 
                 usecols=['company', 'rank', 'revenues', 'revenue_change', 'profits'])
df.head()
# Out:
#                     company  rank  revenues  revenue_change  profits
# 0                   Walmart     1    485873             0.8  13643.0
# 1                State Grid     2    315199            -4.4   9571.3
# 2             Sinopec Group     3    267518            -9.1   1257.9
# 3  China National Petroleum     4    262573           -12.3   1867.5
# 4              Toyota Motor     5    254694             7.7  16899.3

# %% [markdown]
# ### Ładowanie wybranych kolumn z pliku CSV na podstawie wyrażenia lambda

# %%
url = "https://raw.githubusercontent.com/marianwitkowski/bs-datasets/main/f500.csv"
df = pd.read_csv(url, sep=",",  
                 usecols=lambda c: c.startswith('p')) #tylko kolumny zaczynające się od litery 'p'
df.head()
# Out:
#    profits  profit_change  previous_rank
# 0  13643.0           -7.2              1
# 1   9571.3           -6.2              2
# 2   1257.9          -65.0              4
# 3   1867.5          -73.7              3
# 4  16899.3          -12.3              8

# %% [markdown]
# ### Ładowanie pliku CSV z określaniem indeksu

# %%
url = "https://raw.githubusercontent.com/marianwitkowski/bs-datasets/main/f500.csv"
df = pd.read_csv(url, sep=",", index_col='company' ) 
df.head()
# Out:
#                           rank  revenues  revenue_change  profits  assets  \
# company
# Walmart                      1    485873             0.8  13643.0  198825
# State Grid                   2    315199            -4.4   9571.3  489838
# Sinopec Group                3    267518            -9.1   1257.9  310726
# China National Petroleum     4    262573           -12.3   1867.5  585619
# Toyota Motor                 5    254694             7.7  16899.3  437575
#
#                           profit_change                  ceo  \
# company
# Walmart                            -7.2  C. Douglas McMillon
# State Grid                         -6.2              Kou Wei
# Sinopec Group                     -65.0            Wang Yupu
# China National Petroleum          -73.7        Zhang Jianhua
# Toyota Motor                      -12.3          Akio Toyoda
#
#                                           industry                  sector  \
# company
# Walmart                      General Merchandisers               Retailing
# State Grid                               Utilities                  Energy
# Sinopec Group                   Petroleum Refining                  Energy
# China National Petroleum        Petroleum Refining                  Energy
# Toyota Motor              Motor Vehicles and Parts  Motor Vehicles & Parts
#
#                           previous_rank country      hq_location  \
# company
# Walmart                               1     USA  Bentonville, AR
# State Grid                            2   China   Beijing, China
# Sinopec Group                         4   China   Beijing, China
# China National Petroleum              3   China   Beijing, China
# Toyota Motor                          8   Japan    Toyota, Japan
#
#                                                website  \
# company
# Walmart                         http://www.walmart.com
# State Grid                      http://www.sgcc.com.cn
# Sinopec Group                   http://www.sinopec.com
# China National Petroleum        http://www.cnpc.com.cn
# Toyota Motor              http://www.toyota-global.com
#
#                           years_on_global_500_list  employees  \
# company
# Walmart                                         23    2300000
# State Grid                                      17     926067
# Sinopec Group                                   19     713288
# China National Petroleum                        17    1512048
# Toyota Motor                                    23     364445
#
#                           total_stockholder_equity
# company
# Walmart                                      77798
# State Grid                                  209456
# Sinopec Group                               106523
# China National Petroleum                    301893
# Toyota Motor                                157210

# %% [markdown]
# ### Ładowanie pliku CSV - pobieranie określonej liczby wierszy

# %%
url = "https://raw.githubusercontent.com/marianwitkowski/bs-datasets/main/f500.csv"
df = pd.read_csv(url, sep=",", nrows=10 ) 
df
# Out:
#                     company  rank  revenues  revenue_change  profits  assets  \
# 0                   Walmart     1    485873             0.8  13643.0  198825
# 1                State Grid     2    315199            -4.4   9571.3  489838
# 2             Sinopec Group     3    267518            -9.1   1257.9  310726
# 3  China National Petroleum     4    262573           -12.3   1867.5  585619
# 4              Toyota Motor     5    254694             7.7  16899.3  437575
# 5                Volkswagen     6    240264             1.5   5937.3  432116
# 6         Royal Dutch Shell     7    240033           -11.8   4575.0  411275
# 7        Berkshire Hathaway     8    223604             6.1  24074.0  620854
# 8                     Apple     9    215639            -7.7  45687.0  321686
# 9               Exxon Mobil    10    205004           -16.7   7840.0  330314
#
#    profit_change                  ceo  \
# 0           -7.2  C. Douglas McMillon
# 1           -6.2              Kou Wei
# 2          -65.0            Wang Yupu
# 3          -73.7        Zhang Jianhua
# 4          -12.3          Akio Toyoda
# 5            NaN      Matthias Muller
# 6          135.9      Ben van Beurden
# 7            NaN    Warren E. Buffett
# 8          -14.4      Timothy D. Cook
# 9          -51.5      Darren W. Woods
#
#                                    industry                  sector  \
# 0                     General Merchandisers               Retailing
# 1                                 Utilities                  Energy
# 2                        Petroleum Refining                  Energy
# 3                        Petroleum Refining                  Energy
# 4                  Motor Vehicles and Parts  Motor Vehicles & Parts
# 5                  Motor Vehicles and Parts  Motor Vehicles & Parts
# 6                        Petroleum Refining                  Energy
# 7  Insurance: Property and Casualty (Stock)              Financials
# 8               Computers, Office Equipment              Technology
# 9                        Petroleum Refining                  Energy
#
#    previous_rank      country             hq_location  \
# 0              1          USA         Bentonville, AR
# 1              2        China          Beijing, China
# 2              4        China          Beijing, China
# 3              3        China          Beijing, China
# 4              8        Japan           Toyota, Japan
# 5              7      Germany      Wolfsburg, Germany
# 6              5  Netherlands  The Hague, Netherlands
# 7             11          USA               Omaha, NE
# 8              9          USA           Cupertino, CA
# 9              6          USA              Irving, TX
#
#                             website  years_on_global_500_list  employees  \
# 0            http://www.walmart.com                        23    2300000
# 1            http://www.sgcc.com.cn                        17     926067
# 2            http://www.sinopec.com                        19     713288
# 3            http://www.cnpc.com.cn                        17    1512048
# 4      http://www.toyota-global.com                        23     364445
# 5         http://www.volkswagen.com                        23     626715
# 6              http://www.shell.com                        23      89000
# 7  http://www.berkshirehathaway.com                        21     367700
# 8              http://www.apple.com                        15     116000
# 9         http://www.exxonmobil.com                        23      72700
#
#    total_stockholder_equity
# 0                     77798
# 1                    209456
# 2                    106523
# 3                    301893
# 4                    157210
# 5                     97753
# 6                    186646
# 7                    283001
# 8                    128249
# 9                    167325

# %% [markdown]
# ### Ładowanie pliku CSV - pomijanie linii początkowych / końcowych oraz linii komentarzy

# %%
url = "https://raw.githubusercontent.com/marianwitkowski/bs-datasets/main/f500.csv"
df = pd.read_csv(url, sep=",", skiprows=10, skipfooter=10, 
                 comment="#",  # linie zaczynające się od znaku # nie będą wczytywane
                 header=None) 
df
# Out:
#                            0    1       2     3       4       5      6   \
# 0                 Exxon Mobil   10  205004 -16.7  7840.0  330314  -51.5
# 1                    McKesson   11  198533   3.1  5070.0   60969  124.5
# 2                          BP   12  186606 -17.4   115.0  263316    NaN
# 3          UnitedHealth Group   13  184840  17.7  7017.0  122810   20.7
# 4                  CVS Health   14  177526  15.8  5317.0   94462    1.5
# ..                        ...  ...     ...   ...     ...     ...    ...
# 476                 GS Caltex  486   22207 -11.4  1221.1   15969   42.1
# 477         Ultrapar Holdings  487   22167  -2.3   447.5    7426   -0.8
# 478                Xiamen C&D  488   22145   6.6   280.2   21729   15.6
# 479            Sears Holdings  489   22138 -12.0 -2221.0    9362    NaN
# 480  China General Technology  490   22113 -20.1   413.6   20860  -20.8
#
#                      7                                         8   \
# 0       Darren W. Woods                        Petroleum Refining
# 1    John H. Hammergren                  Wholesalers: Health Care
# 2      Robert W. Dudley                        Petroleum Refining
# 3    Stephen J. Hemsley   Health Care: Insurance and Managed Care
# 4        Larry J. Merlo  Health Care: Pharmacy and Other Services
# ..                  ...                                       ...
# 476         Jin-Soo Huh                        Petroleum Refining
# 477     Thilo Mannhardt                                    Energy
# 478       Huang Wenzhou                                   Trading
# 479   Edward S. Lampert                     General Merchandisers
# 480         Xu Xianping                 Engineering, Construction
#
#                              9    10           11                   12  \
# 0                        Energy    6          USA           Irving, TX
# 1                   Wholesalers   12          USA    San Francisco, CA
# 2                        Energy   10      Britain      London, Britain
# 3                   Health Care   17          USA       Minnetonka, MN
# 4                   Health Care   18          USA       Woonsocket, RI
# ..                          ...  ...          ...                  ...
# 476                      Energy  431  South Korea   Seoul, South Korea
# 477                      Energy  474       Brazil    Sao Paulo, Brazil
# 478                 Wholesalers    0        China        Xiamen, China
# 479                   Retailing  425          USA  Hoffman Estates, IL
# 480  Engineering & Construction  383        China       Beijing, China
#
#                                    13  14      15      16
# 0           http://www.exxonmobil.com  23   72700  167325
# 1             http://www.mckesson.com  23   64500   11095
# 2                   http://www.bp.com  23   74500   95286
# 3    http://www.unitedhealthgroup.com  21  230000   38274
# 4            http://www.cvshealth.com  22  204000   36830
# ..                                ...  ..     ...     ...
# 476           http://www.gscaltex.com   6    2949    8150
# 477           http://www.ultra.com.br   8   15173    2621
# 478           http://www.chinacdc.com   1   18381    3985
# 479      http://www.searsholdings.com  23  140000   -3824
# 480        http://www.genertec.com.cn   4   38589    5114
#
# [481 rows x 17 columns]

# %% [markdown]
# ### Ładowanie pliku CSV - interpretacja wartości NaN

# %%
url = "https://raw.githubusercontent.com/marianwitkowski/bs-datasets/main/f500.csv"
df = pd.read_csv(url, sep=",", na_values=['?','*']) 
df.head()
# Out:
#                     company  rank  revenues  revenue_change  profits  assets  \
# 0                   Walmart     1    485873             0.8  13643.0  198825
# 1                State Grid     2    315199            -4.4   9571.3  489838
# 2             Sinopec Group     3    267518            -9.1   1257.9  310726
# 3  China National Petroleum     4    262573           -12.3   1867.5  585619
# 4              Toyota Motor     5    254694             7.7  16899.3  437575
#
#    profit_change                  ceo                  industry  \
# 0           -7.2  C. Douglas McMillon     General Merchandisers
# 1           -6.2              Kou Wei                 Utilities
# 2          -65.0            Wang Yupu        Petroleum Refining
# 3          -73.7        Zhang Jianhua        Petroleum Refining
# 4          -12.3          Akio Toyoda  Motor Vehicles and Parts
#
#                    sector  previous_rank country      hq_location  \
# 0               Retailing              1     USA  Bentonville, AR
# 1                  Energy              2   China   Beijing, China
# 2                  Energy              4   China   Beijing, China
# 3                  Energy              3   China   Beijing, China
# 4  Motor Vehicles & Parts              8   Japan    Toyota, Japan
#
#                         website  years_on_global_500_list  employees  \
# 0        http://www.walmart.com                        23    2300000
# 1        http://www.sgcc.com.cn                        17     926067
# 2        http://www.sinopec.com                        19     713288
# 3        http://www.cnpc.com.cn                        17    1512048
# 4  http://www.toyota-global.com                        23     364445
#
#    total_stockholder_equity
# 0                     77798
# 1                    209456
# 2                    106523
# 3                    301893
# 4                    157210

# %% [markdown]
# ### Ładowanie pliku CSV - określanie typu kolumn

# %%
url = "https://raw.githubusercontent.com/marianwitkowski/bs-datasets/main/f500.csv"
df = pd.read_csv(url, sep=",", dtype={
    'rank' : 'int16', 'revenue_change' : 'float16',  'previous_rank' : 'uint16'
}) 
df.head()
# Out:
#                     company  rank  revenues  revenue_change  profits  assets  \
# 0                   Walmart     1    485873        0.799805  13643.0  198825
# 1                State Grid     2    315199       -4.398438   9571.3  489838
# 2             Sinopec Group     3    267518       -9.101562   1257.9  310726
# 3  China National Petroleum     4    262573      -12.296875   1867.5  585619
# 4              Toyota Motor     5    254694        7.699219  16899.3  437575
#
#    profit_change                  ceo                  industry  \
# 0           -7.2  C. Douglas McMillon     General Merchandisers
# 1           -6.2              Kou Wei                 Utilities
# 2          -65.0            Wang Yupu        Petroleum Refining
# 3          -73.7        Zhang Jianhua        Petroleum Refining
# 4          -12.3          Akio Toyoda  Motor Vehicles and Parts
#
#                    sector  previous_rank country      hq_location  \
# 0               Retailing              1     USA  Bentonville, AR
# 1                  Energy              2   China   Beijing, China
# 2                  Energy              4   China   Beijing, China
# 3                  Energy              3   China   Beijing, China
# 4  Motor Vehicles & Parts              8   Japan    Toyota, Japan
#
#                         website  years_on_global_500_list  employees  \
# 0        http://www.walmart.com                        23    2300000
# 1        http://www.sgcc.com.cn                        17     926067
# 2        http://www.sinopec.com                        19     713288
# 3        http://www.cnpc.com.cn                        17    1512048
# 4  http://www.toyota-global.com                        23     364445
#
#    total_stockholder_equity
# 0                     77798
# 1                    209456
# 2                    106523
# 3                    301893
# 4                    157210

# %% [markdown]
# ### Ładowanie pliku CSV - transformacja kolumns

# %%
url = "https://raw.githubusercontent.com/marianwitkowski/bs-datasets/main/f500.csv"
df = pd.read_csv(url, sep=",", converters={
    'rank' : lambda x:int(x)<=10 
}) 
df.head()
# Out:
#                     company  rank  revenues  revenue_change  profits  assets  \
# 0                   Walmart  True    485873             0.8  13643.0  198825
# 1                State Grid  True    315199            -4.4   9571.3  489838
# 2             Sinopec Group  True    267518            -9.1   1257.9  310726
# 3  China National Petroleum  True    262573           -12.3   1867.5  585619
# 4              Toyota Motor  True    254694             7.7  16899.3  437575
#
#    profit_change                  ceo                  industry  \
# 0           -7.2  C. Douglas McMillon     General Merchandisers
# 1           -6.2              Kou Wei                 Utilities
# 2          -65.0            Wang Yupu        Petroleum Refining
# 3          -73.7        Zhang Jianhua        Petroleum Refining
# 4          -12.3          Akio Toyoda  Motor Vehicles and Parts
#
#                    sector  previous_rank country      hq_location  \
# 0               Retailing              1     USA  Bentonville, AR
# 1                  Energy              2   China   Beijing, China
# 2                  Energy              4   China   Beijing, China
# 3                  Energy              3   China   Beijing, China
# 4  Motor Vehicles & Parts              8   Japan    Toyota, Japan
#
#                         website  years_on_global_500_list  employees  \
# 0        http://www.walmart.com                        23    2300000
# 1        http://www.sgcc.com.cn                        17     926067
# 2        http://www.sinopec.com                        19     713288
# 3        http://www.cnpc.com.cn                        17    1512048
# 4  http://www.toyota-global.com                        23     364445
#
#    total_stockholder_equity
# 0                     77798
# 1                    209456
# 2                    106523
# 3                    301893
# 4                    157210

# %% [markdown]
# ### Ładowanie skompresowanego pliku CSV

# %%
url = "http://51.91.120.89/extras/sales-records.zip"
df = pd.read_csv(url, compression='zip') 
df.head()
# Out:
#                          Region           Country  Item Type Sales Channel  \
# 0            Sub-Saharan Africa      South Africa     Fruits       Offline
# 1  Middle East and North Africa           Morocco    Clothes        Online
# 2         Australia and Oceania  Papua New Guinea       Meat       Offline
# 3            Sub-Saharan Africa          Djibouti    Clothes       Offline
# 4                        Europe          Slovakia  Beverages       Offline
#
#   Order Priority  Order Date   Order ID   Ship Date  Units Sold  Unit Price  \
# 0              M   7/27/2012  443368995   7/28/2012        1593        9.33
# 1              M   9/14/2013  667593514  10/19/2013        4611      109.28
# 2              M   5/15/2015  940995585    6/4/2015         360      421.89
# 3              H   5/17/2017  880811536    7/2/2017         562      109.28
# 4              L  10/26/2016  174590194   12/4/2016        3973       47.45
#
#    Unit Cost  Total Revenue  Total Cost  Total Profit
# 0       6.92       14862.69    11023.56       3839.13
# 1      35.84      503890.08   165258.24     338631.84
# 2     364.69      151880.40   131288.40      20592.00
# 3      35.84       61415.36    20142.08      41273.28
# 4      31.79      188518.85   126301.67      62217.18

# %% [markdown]
# ### Ładowanie danych z pliku CSV w porcjach

# %%
df = pd.DataFrame()
url = "http://51.91.120.89/extras/sales-records.zip"
df_gen = pd.read_csv(url, compression='zip', chunksize=100_000) 
for df_chunk in df_gen:
    df = df.append(df_chunk)
    print(".",  end='')
df.head()
# Out:
# ..........
#                          Region           Country  Item Type Sales Channel  \
# 0            Sub-Saharan Africa      South Africa     Fruits       Offline
# 1  Middle East and North Africa           Morocco    Clothes        Online
# 2         Australia and Oceania  Papua New Guinea       Meat       Offline
# 3            Sub-Saharan Africa          Djibouti    Clothes       Offline
# 4                        Europe          Slovakia  Beverages       Offline
#
#   Order Priority  Order Date   Order ID   Ship Date  Units Sold  Unit Price  \
# 0              M   7/27/2012  443368995   7/28/2012        1593        9.33
# 1              M   9/14/2013  667593514  10/19/2013        4611      109.28
# 2              M   5/15/2015  940995585    6/4/2015         360      421.89
# 3              H   5/17/2017  880811536    7/2/2017         562      109.28
# 4              L  10/26/2016  174590194   12/4/2016        3973       47.45
#
#    Unit Cost  Total Revenue  Total Cost  Total Profit
# 0       6.92       14862.69    11023.56       3839.13
# 1      35.84      503890.08   165258.24     338631.84
# 2     364.69      151880.40   131288.40      20592.00
# 3      35.84       61415.36    20142.08      41273.28
# 4      31.79      188518.85   126301.67      62217.18
