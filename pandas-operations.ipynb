# %% [markdown]
# ## Pandas - podstawowe operacje na obiektach DataFrame
#
# #### Autor: Marian Witkowski marian.witkowski[at]gmail.com
#
# #### Niniejszy materiał może być używany w celach dydaktyczych pod warunkem poinformowania o autorze.
#
# Przykład użycia najczęstszych operacji i technik manulacji na obiektach DataFrame w Pandas:
# - ładowanie danych z CSV
# - dostęp do kolumn
# - indeksowanie/wybieranie danych
# - filtrowanie
# - zmiana typu danych
# - informacje statystyczne o obiekcie
# - transformacja i sortowanie danych
# - grupowanie
# - deduplikacja
# - budowanie rankingu
# - wypełnianie wartości NaN (missing values)
# - łączenie danych
#
# <img src='http://51.91.120.89/itm/p.png' border=0 />

# %%
import numpy as np
import pandas as pd
import warnings

warnings.filterwarnings("ignore")

# %% [markdown]
# ## Ładowanie danych do DataFrame

# %%
df = pd.read_csv("https://bit.ly/3io3vC6")

# %% [markdown]
# ### Pokaż początkowe rekordy w DataFrame

# %%
df.head(10)
# Out:
#        country  year         pop continent  lifeExp   gdpPercap
# 0  Afghanistan  1952   8425333.0      Asia   28.801  779.445314
# 1  Afghanistan  1957   9240934.0      Asia   30.332  820.853030
# 2  Afghanistan  1962  10267083.0      Asia   31.997  853.100710
# 3  Afghanistan  1967  11537966.0      Asia   34.020  836.197138
# 4  Afghanistan  1972  13079460.0      Asia   36.088  739.981106
# 5  Afghanistan  1977  14880372.0      Asia   38.438  786.113360
# 6  Afghanistan  1982  12881816.0      Asia   39.854  978.011439
# 7  Afghanistan  1987  13867957.0      Asia   40.822  852.395945
# 8  Afghanistan  1992  16317921.0      Asia   41.674  649.341395
# 9  Afghanistan  1997  22227415.0      Asia   41.763  635.341351

# %% [markdown]
# ### Pokaż końcowe rekordy w DataFrame

# %%
df.tail(10) # w parametrze liczba rekordów do pokazania
# Out:
#        country  year         pop continent  lifeExp   gdpPercap
# 1694  Zimbabwe  1962   4277736.0    Africa   52.358  527.272182
# 1695  Zimbabwe  1967   4995432.0    Africa   53.995  569.795071
# 1696  Zimbabwe  1972   5861135.0    Africa   55.635  799.362176
# 1697  Zimbabwe  1977   6642107.0    Africa   57.674  685.587682
# 1698  Zimbabwe  1982   7636524.0    Africa   60.363  788.855041
# 1699  Zimbabwe  1987   9216418.0    Africa   62.351  706.157306
# 1700  Zimbabwe  1992  10704340.0    Africa   60.377  693.420786
# 1701  Zimbabwe  1997  11404948.0    Africa   46.809  792.449960
# 1702  Zimbabwe  2002  11926563.0    Africa   39.989  672.038623
# 1703  Zimbabwe  2007  12311143.0    Africa   43.487  469.709298

# %% [markdown]
# ### Pobranie danych z DataFrame

# %%
# pojedyncza kolumna
df["country"]
# Out:
# 0       Afghanistan
# 1       Afghanistan
# 2       Afghanistan
# 3       Afghanistan
# 4       Afghanistan
#            ...
# 1699       Zimbabwe
# 1700       Zimbabwe
# 1701       Zimbabwe
# 1702       Zimbabwe
# 1703       Zimbabwe
# Name: country, Length: 1704, dtype: object

# %%
# pojedyncza kolumna - notacja kropkowa
df.country
# Out:
# 0       Afghanistan
# 1       Afghanistan
# 2       Afghanistan
# 3       Afghanistan
# 4       Afghanistan
#            ...
# 1699       Zimbabwe
# 1700       Zimbabwe
# 1701       Zimbabwe
# 1702       Zimbabwe
# 1703       Zimbabwe
# Name: country, Length: 1704, dtype: object

# %%
# wiele kolumn
df[ ["country","continent","gdpPercap"] ]
# Out:
#           country continent   gdpPercap
# 0     Afghanistan      Asia  779.445314
# 1     Afghanistan      Asia  820.853030
# 2     Afghanistan      Asia  853.100710
# 3     Afghanistan      Asia  836.197138
# 4     Afghanistan      Asia  739.981106
# ...           ...       ...         ...
# 1699     Zimbabwe    Africa  706.157306
# 1700     Zimbabwe    Africa  693.420786
# 1701     Zimbabwe    Africa  792.449960
# 1702     Zimbabwe    Africa  672.038623
# 1703     Zimbabwe    Africa  469.709298
#
# [1704 rows x 3 columns]

# %%
# określenie pobieranych wierszy i kolumn
# pobranie wierszy od indeksu 1 do 10 włącznie i kolumn "country","continent","gdpPercap"
df.loc[ 1:10,  ["country","continent","gdpPercap"]  ]
# Out:
#         country continent   gdpPercap
# 1   Afghanistan      Asia  820.853030
# 2   Afghanistan      Asia  853.100710
# 3   Afghanistan      Asia  836.197138
# 4   Afghanistan      Asia  739.981106
# 5   Afghanistan      Asia  786.113360
# 6   Afghanistan      Asia  978.011439
# 7   Afghanistan      Asia  852.395945
# 8   Afghanistan      Asia  649.341395
# 9   Afghanistan      Asia  635.341351
# 10  Afghanistan      Asia  726.734055

# %%
# pobranie ostatnich 10 wierszy i kolumny o offsecie 0, 2, 4
df.iloc[ -10: , [0,2,4] ]
# Out:
#        country         pop  lifeExp
# 1694  Zimbabwe   4277736.0   52.358
# 1695  Zimbabwe   4995432.0   53.995
# 1696  Zimbabwe   5861135.0   55.635
# 1697  Zimbabwe   6642107.0   57.674
# 1698  Zimbabwe   7636524.0   60.363
# 1699  Zimbabwe   9216418.0   62.351
# 1700  Zimbabwe  10704340.0   60.377
# 1701  Zimbabwe  11404948.0   46.809
# 1702  Zimbabwe  11926563.0   39.989
# 1703  Zimbabwe  12311143.0   43.487

# %%
# pobierz wszystkie wiersze i 2 ostatnie kolumny
df.iloc[ : , -2:]
# Out:
#       lifeExp   gdpPercap
# 0      28.801  779.445314
# 1      30.332  820.853030
# 2      31.997  853.100710
# 3      34.020  836.197138
# 4      36.088  739.981106
# ...       ...         ...
# 1699   62.351  706.157306
# 1700   60.377  693.420786
# 1701   46.809  792.449960
# 1702   39.989  672.038623
# 1703   43.487  469.709298
#
# [1704 rows x 2 columns]

# %%
# pobierz co 3-ci wiersz i co 2-gą kolumną
df.iloc[ ::3, ::2 ]
# Out:
#           country         pop  lifeExp
# 0     Afghanistan   8425333.0   28.801
# 3     Afghanistan  11537966.0   34.020
# 6     Afghanistan  12881816.0   39.854
# 9     Afghanistan  22227415.0   41.763
# 12        Albania   1282697.0   55.230
# ...           ...         ...      ...
# 1689       Zambia   9417789.0   40.238
# 1692     Zimbabwe   3080907.0   48.451
# 1695     Zimbabwe   4995432.0   53.995
# 1698     Zimbabwe   7636524.0   60.363
# 1701     Zimbabwe  11404948.0   46.809
#
# [568 rows x 3 columns]

# %% [markdown]
# ### Pobranie informacji o kolumnach

# %%
df.columns
# Out:
# Index(['country', 'year', 'pop', 'continent', 'lifeExp', 'gdpPercap'], dtype='object')

# %% [markdown]
# ### Pobranie informacji o typach danych kolumn

# %%
df.dtypes
# Out:
# country       object
# year           int64
# pop          float64
# continent     object
# lifeExp      float64
# gdpPercap    float64
# dtype: object

# %% [markdown]
# ### Zmiana typu kolumny w DataFrame

# %%
df["year"] = df["year"].astype("uint16") # liczba 16-bitowa bez znaku
df["lifeExp"] = df["lifeExp"].astype("float32") # float 32-bitowy

# %% [markdown]
# ### Metryki statystyczne danych w DataFrame

# %%
df.describe()
# Out:
#              year           pop      lifeExp      gdpPercap
# count  1704.00000  1.704000e+03  1704.000000    1704.000000
# mean   1979.50000  2.960121e+07    59.474384    7215.327081
# std      17.26533  1.061579e+08    12.917107    9857.454543
# min    1952.00000  6.001100e+04    23.599001     241.165876
# 25%    1965.75000  2.793664e+06    48.197999    1202.060309
# 50%    1979.50000  7.023596e+06    60.712500    3531.846988
# 75%    1993.25000  1.958522e+07    70.845501    9325.462346
# max    2007.00000  1.318683e+09    82.602997  113523.132900

# %% [markdown]
# ### Ilość miejsca zajmowanego w RAM przez DataFrame

# %%
df.memory_usage(deep=True)
# Out:
# Index           128
# country      111288
# year           3408
# pop           13632
# continent    107184
# lifeExp        6816
# gdpPercap     13632
# dtype: int64

# %% [markdown]
# ### Sortowanie danych wg kolumn(y)

# %%
df.sort_values('year')
# Out:
#                  country  year          pop continent    lifeExp     gdpPercap
# 0            Afghanistan  1952    8425333.0      Asia  28.801001    779.445314
# 528               France  1952   42459667.0    Europe  67.410004   7029.809327
# 540                Gabon  1952     420702.0    Africa  37.002998   4293.476475
# 1656  West Bank and Gaza  1952    1030585.0      Asia  43.160000   1515.592329
# 552               Gambia  1952     284320.0    Africa  30.000000    485.230659
# ...                  ...   ...          ...       ...        ...           ...
# 1127               Niger  2007   12894865.0    Africa  56.867001    619.676892
# 1139             Nigeria  2007  135031164.0    Africa  46.859001   2013.977305
# 1151              Norway  2007    4627926.0    Europe  80.195999  49357.190170
# 1175            Pakistan  2007  169270617.0      Asia  65.483002   2605.947580
# 1703            Zimbabwe  2007   12311143.0    Africa  43.487000    469.709298
#
# [1704 rows x 6 columns]

# %%
df.sort_values(['country','pop'], ascending=[True,False])
# Out:
#           country  year         pop continent    lifeExp   gdpPercap
# 11    Afghanistan  2007  31889923.0      Asia  43.827999  974.580338
# 10    Afghanistan  2002  25268405.0      Asia  42.129002  726.734055
# 9     Afghanistan  1997  22227415.0      Asia  41.763000  635.341351
# 8     Afghanistan  1992  16317921.0      Asia  41.674000  649.341395
# 5     Afghanistan  1977  14880372.0      Asia  38.438000  786.113360
# ...           ...   ...         ...       ...        ...         ...
# 1696     Zimbabwe  1972   5861135.0    Africa  55.634998  799.362176
# 1695     Zimbabwe  1967   4995432.0    Africa  53.994999  569.795071
# 1694     Zimbabwe  1962   4277736.0    Africa  52.358002  527.272182
# 1693     Zimbabwe  1957   3646340.0    Africa  50.469002  518.764268
# 1692     Zimbabwe  1952   3080907.0    Africa  48.451000  406.884115
#
# [1704 rows x 6 columns]

# %% [markdown]
# ### Sortowanie danych wg indeksu

# %%
df.sort_index(ascending=False)
# Out:
#           country  year         pop continent    lifeExp   gdpPercap
# 1703     Zimbabwe  2007  12311143.0    Africa  43.487000  469.709298
# 1702     Zimbabwe  2002  11926563.0    Africa  39.988998  672.038623
# 1701     Zimbabwe  1997  11404948.0    Africa  46.808998  792.449960
# 1700     Zimbabwe  1992  10704340.0    Africa  60.376999  693.420786
# 1699     Zimbabwe  1987   9216418.0    Africa  62.351002  706.157306
# ...           ...   ...         ...       ...        ...         ...
# 4     Afghanistan  1972  13079460.0      Asia  36.088001  739.981106
# 3     Afghanistan  1967  11537966.0      Asia  34.020000  836.197138
# 2     Afghanistan  1962  10267083.0      Asia  31.997000  853.100710
# 1     Afghanistan  1957   9240934.0      Asia  30.332001  820.853030
# 0     Afghanistan  1952   8425333.0      Asia  28.801001  779.445314
#
# [1704 rows x 6 columns]

# %% [markdown]
# ### Pobieranie największych wartości na podstawie kolumny

# %%
df.nlargest(5, 'pop')
# Out:
#     country  year           pop continent    lifeExp    gdpPercap
# 299   China  2007  1.318683e+09      Asia  72.960999  4959.114854
# 298   China  2002  1.280400e+09      Asia  72.028000  3119.280896
# 297   China  1997  1.230075e+09      Asia  70.426003  2289.234136
# 296   China  1992  1.164970e+09      Asia  68.690002  1655.784158
# 707   India  2007  1.110396e+09      Asia  64.697998  2452.210407

# %% [markdown]
# ### Pobieranie najmniejszych wartości na podstawie kolumny

# %%
df.nsmallest(5, 'lifeExp')
# Out:
#            country  year        pop continent    lifeExp    gdpPercap
# 1292        Rwanda  1992  7290203.0    Africa  23.599001   737.068595
# 0      Afghanistan  1952  8425333.0      Asia  28.801001   779.445314
# 552         Gambia  1952   284320.0    Africa  30.000000   485.230659
# 36          Angola  1952  4232095.0    Africa  30.014999  3520.610273
# 1344  Sierra Leone  1952  2143249.0    Africa  30.330999   879.787736

# %% [markdown]
# ### Zmiana nazw kolumn

# %%
# wszystkie kolumny zapisane małymi literami
df.columns = df.columns.str.lower()
df.head(3)
# Out:
#        country  year         pop continent    lifeexp   gdppercap
# 0  Afghanistan  1952   8425333.0      Asia  28.801001  779.445314
# 1  Afghanistan  1957   9240934.0      Asia  30.332001  820.853030
# 2  Afghanistan  1962  10267083.0      Asia  31.997000  853.100710

# %%
# użycie dedykowane metody do zmiany nazwy kolumn(y)
df.rename(columns={"country":"Country", "gdppercap":"GDP_per_cap"}, inplace=True)
df.head(3)
# Out:
#        Country  year         pop continent    lifeexp  GDP_per_cap
# 0  Afghanistan  1952   8425333.0      Asia  28.801001   779.445314
# 1  Afghanistan  1957   9240934.0      Asia  30.332001   820.853030
# 2  Afghanistan  1962  10267083.0      Asia  31.997000   853.100710

# %% [markdown]
# ### Przekształcanie zawartości kolumny
#
# Dodatkowa kolumna "pop_range" będzie przyjmować wartość z zakresu L,M,H w zależności o wartości kolumny "pop" wg reguły:
#
# - L dla <50mln
# - M dla >=50mln i <100mln
# - H dla >=100mln

# %%
def apply_pop(x):
    if x<50_000_000:
        return "L"
    if x<100_000_000:
        return "M"
    return "H"

df["pop_range"] = df["pop"].apply(apply_pop)
df.head(3)
# Out:
#        Country  year         pop continent    lifeexp  GDP_per_cap pop_range
# 0  Afghanistan  1952   8425333.0      Asia  28.801001   779.445314         L
# 1  Afghanistan  1957   9240934.0      Asia  30.332001   820.853030         L
# 2  Afghanistan  1962  10267083.0      Asia  31.997000   853.100710         L

# %% [markdown]
# ### Mapowanie wartości w kolumnie
#
# zmapuj kolumnę "pop_range" wg schematu: dla L wartość Low, dla M - Medium, dla H - High

# %%
df.pop_range = df.pop_range.map({
    "L" : "Low", "M" : "Medium", "H" : "High"
})
df.head()
# Out:
#        Country  year         pop continent    lifeexp  GDP_per_cap pop_range
# 0  Afghanistan  1952   8425333.0      Asia  28.801001   779.445314       Low
# 1  Afghanistan  1957   9240934.0      Asia  30.332001   820.853030       Low
# 2  Afghanistan  1962  10267083.0      Asia  31.997000   853.100710       Low
# 3  Afghanistan  1967  11537966.0      Asia  34.020000   836.197138       Low
# 4  Afghanistan  1972  13079460.0      Asia  36.088001   739.981106       Low

# %% [markdown]
# ### Usuwanie kolumn(y)

# %%
df.drop(columns='pop') # pojedyncza kolumna
# Out:
#           Country  year continent    lifeexp  GDP_per_cap pop_range
# 0     Afghanistan  1952      Asia  28.801001   779.445314       Low
# 1     Afghanistan  1957      Asia  30.332001   820.853030       Low
# 2     Afghanistan  1962      Asia  31.997000   853.100710       Low
# 3     Afghanistan  1967      Asia  34.020000   836.197138       Low
# 4     Afghanistan  1972      Asia  36.088001   739.981106       Low
# ...           ...   ...       ...        ...          ...       ...
# 1699     Zimbabwe  1987    Africa  62.351002   706.157306       Low
# 1700     Zimbabwe  1992    Africa  60.376999   693.420786       Low
# 1701     Zimbabwe  1997    Africa  46.808998   792.449960       Low
# 1702     Zimbabwe  2002    Africa  39.988998   672.038623       Low
# 1703     Zimbabwe  2007    Africa  43.487000   469.709298       Low
#
# [1704 rows x 6 columns]

# %%
df.drop(columns=['pop','continent']) # wiele kolumn
# Out:
#           Country  year    lifeexp  GDP_per_cap pop_range
# 0     Afghanistan  1952  28.801001   779.445314       Low
# 1     Afghanistan  1957  30.332001   820.853030       Low
# 2     Afghanistan  1962  31.997000   853.100710       Low
# 3     Afghanistan  1967  34.020000   836.197138       Low
# 4     Afghanistan  1972  36.088001   739.981106       Low
# ...           ...   ...        ...          ...       ...
# 1699     Zimbabwe  1987  62.351002   706.157306       Low
# 1700     Zimbabwe  1992  60.376999   693.420786       Low
# 1701     Zimbabwe  1997  46.808998   792.449960       Low
# 1702     Zimbabwe  2002  39.988998   672.038623       Low
# 1703     Zimbabwe  2007  43.487000   469.709298       Low
#
# [1704 rows x 5 columns]

# %% [markdown]
# ### Przekształcanie kolumny typu object z wykorzystanie funkcji obiektów string

# %%
df.Country = df.Country.str.upper() # .str - rzutowanie na obiekt klasy string
df.head()
# Out:
#        Country  year         pop continent    lifeexp  GDP_per_cap pop_range
# 0  AFGHANISTAN  1952   8425333.0      Asia  28.801001   779.445314       Low
# 1  AFGHANISTAN  1957   9240934.0      Asia  30.332001   820.853030       Low
# 2  AFGHANISTAN  1962  10267083.0      Asia  31.997000   853.100710       Low
# 3  AFGHANISTAN  1967  11537966.0      Asia  34.020000   836.197138       Low
# 4  AFGHANISTAN  1972  13079460.0      Asia  36.088001   739.981106       Low

# %% [markdown]
# ### Pobranie losowych wierszy z DataFrame

# %%
# ilościowo - z parametrem "n"
df.sample(n=10, random_state=42)
# Out:
#                        Country  year         pop continent    lifeexp  \
# 1046                   MYANMAR  1962  23634436.0      Asia  45.108002
# 745                    IRELAND  1957   2878220.0    Europe  68.900002
# 785                    JAMAICA  1977   2156814.0  Americas  70.110001
# 367              COTE D'IVOIRE  1987  10761098.0    Africa  54.654999
# 1029                   MOROCCO  1997  28529501.0    Africa  67.660004
# 1648                   VIETNAM  1972  44655014.0      Asia  50.254002
# 259   CENTRAL AFRICAN REPUBLIC  1987   2840009.0    Africa  50.485001
# 1509                    TAIWAN  1997  21628605.0      Asia  75.250000
# 514                   ETHIOPIA  2002  67946797.0    Africa  50.724998
# 1229                    POLAND  1977  34621254.0    Europe  70.669998
#
#        GDP_per_cap pop_range
# 1046    388.000000       Low
# 745    5599.077872       Low
# 785    6650.195573       Low
# 367    2156.956069       Low
# 1029   2982.101858       Low
# 1648    699.501644       Low
# 259     844.876350       Low
# 1509  20206.820980       Low
# 514     530.053532    Medium
# 1229   9508.141454       Low

# %%
# procentowo - z parametrem "frac"
df.sample(frac=0.5/100, random_state=42)
# Out:
#                        Country  year         pop continent    lifeexp  \
# 1046                   MYANMAR  1962  23634436.0      Asia  45.108002
# 745                    IRELAND  1957   2878220.0    Europe  68.900002
# 785                    JAMAICA  1977   2156814.0  Americas  70.110001
# 367              COTE D'IVOIRE  1987  10761098.0    Africa  54.654999
# 1029                   MOROCCO  1997  28529501.0    Africa  67.660004
# 1648                   VIETNAM  1972  44655014.0      Asia  50.254002
# 259   CENTRAL AFRICAN REPUBLIC  1987   2840009.0    Africa  50.485001
# 1509                    TAIWAN  1997  21628605.0      Asia  75.250000
# 514                   ETHIOPIA  2002  67946797.0    Africa  50.724998
#
#        GDP_per_cap pop_range
# 1046    388.000000       Low
# 745    5599.077872       Low
# 785    6650.195573       Low
# 367    2156.956069       Low
# 1029   2982.101858       Low
# 1648    699.501644       Low
# 259     844.876350       Low
# 1509  20206.820980       Low
# 514     530.053532    Medium

# %% [markdown]
# ### Pobranie wartości unikalnym z kolumny

# %%
df.Country.unique()
# Out:
# array(['AFGHANISTAN', 'ALBANIA', 'ALGERIA', 'ANGOLA', 'ARGENTINA',
#        'AUSTRALIA', 'AUSTRIA', 'BAHRAIN', 'BANGLADESH', 'BELGIUM',
#        'BENIN', 'BOLIVIA', 'BOSNIA AND HERZEGOVINA', 'BOTSWANA', 'BRAZIL',
#        'BULGARIA', 'BURKINA FASO', 'BURUNDI', 'CAMBODIA', 'CAMEROON',
#        'CANADA', 'CENTRAL AFRICAN REPUBLIC', 'CHAD', 'CHILE', 'CHINA',
#        'COLOMBIA', 'COMOROS', 'CONGO DEM. REP.', 'CONGO REP.',
#        'COSTA RICA', "COTE D'IVOIRE", 'CROATIA', 'CUBA', 'CZECH REPUBLIC',
#        'DENMARK', 'DJIBOUTI', 'DOMINICAN REPUBLIC', 'ECUADOR', 'EGYPT',
#        'EL SALVADOR', 'EQUATORIAL GUINEA', 'ERITREA', 'ETHIOPIA',
#        'FINLAND', 'FRANCE', 'GABON', 'GAMBIA', 'GERMANY', 'GHANA',
#        'GREECE', 'GUATEMALA', 'GUINEA', 'GUINEA-BISSAU', 'HAITI',
#        'HONDURAS', 'HONG KONG CHINA', 'HUNGARY', 'ICELAND', 'INDIA',
#        'INDONESIA', 'IRAN', 'IRAQ', 'IRELAND', 'ISRAEL', 'ITALY',
#        'JAMAICA', 'JAPAN', 'JORDAN', 'KENYA', 'KOREA DEM. REP.',
#        'KOREA REP.', 'KUWAIT', 'LEBANON', 'LESOTHO', 'LIBERIA', 'LIBYA',
#        'MADAGASCAR', 'MALAWI', 'MALAYSIA', 'MALI', 'MAURITANIA',
#        'MAURITIUS', 'MEXICO', 'MONGOLIA', 'MONTENEGRO', 'MOROCCO',
#        'MOZAMBIQUE', 'MYANMAR', 'NAMIBIA', 'NEPAL', 'NETHERLANDS',
#        'NEW ZEALAND', 'NICARAGUA', 'NIGER', 'NIGERIA', 'NORWAY', 'OMAN',
#        'PAKISTAN', 'PANAMA', 'PARAGUAY', 'PERU', 'PHILIPPINES', 'POLAND',
#        'PORTUGAL', 'PUERTO RICO', 'REUNION', 'ROMANIA', 'RWANDA',
#        'SAO TOME AND PRINCIPE', 'SAUDI ARABIA', 'SENEGAL', 'SERBIA',
#        'SIERRA LEONE', 'SINGAPORE', 'SLOVAK REPUBLIC', 'SLOVENIA',
#        'SOMALIA', 'SOUTH AFRICA', 'SPAIN', 'SRI LANKA', 'SUDAN',
#        'SWAZILAND', 'SWEDEN', 'SWITZERLAND', 'SYRIA', 'TAIWAN',
#        'TANZANIA', 'THAILAND', 'TOGO', 'TRINIDAD AND TOBAGO', 'TUNISIA',
#        'TURKEY', 'UGANDA', 'UNITED KINGDOM', 'UNITED STATES', 'URUGUAY',
#        'VENEZUELA', 'VIETNAM', 'WEST BANK AND GAZA', 'YEMEN REP.',
#        'ZAMBIA', 'ZIMBABWE'], dtype=object)

# %% [markdown]
# ### Pobranie statystyki wartości unikalnych

# %%
df.pop_range.value_counts()
# Out:
# Low       1514
# Medium     113
# High        77
# Name: pop_range, dtype: int64

# %%
df.pop_range.value_counts(normalize=True)
# Out:
# Low       0.888498
# Medium    0.066315
# High      0.045188
# Name: pop_range, dtype: float64

# %% [markdown]
# ### Ustawienie nowego indeksu dla obiektu DataFrame na podstawie kolumny

# %%
df.set_index("Country", inplace=True)
df.head()
# Out:
#              year         pop continent    lifeexp  GDP_per_cap pop_range
# Country
# AFGHANISTAN  1952   8425333.0      Asia  28.801001   779.445314       Low
# AFGHANISTAN  1957   9240934.0      Asia  30.332001   820.853030       Low
# AFGHANISTAN  1962  10267083.0      Asia  31.997000   853.100710       Low
# AFGHANISTAN  1967  11537966.0      Asia  34.020000   836.197138       Low
# AFGHANISTAN  1972  13079460.0      Asia  36.088001   739.981106       Low

# %% [markdown]
# ### Usuwanie/reset indeksu dla obiektu DataFrame

# %%
df.reset_index(inplace=True)
df.head()
# Out:
#        Country  year         pop continent    lifeexp  GDP_per_cap pop_range
# 0  AFGHANISTAN  1952   8425333.0      Asia  28.801001   779.445314       Low
# 1  AFGHANISTAN  1957   9240934.0      Asia  30.332001   820.853030       Low
# 2  AFGHANISTAN  1962  10267083.0      Asia  31.997000   853.100710       Low
# 3  AFGHANISTAN  1967  11537966.0      Asia  34.020000   836.197138       Low
# 4  AFGHANISTAN  1972  13079460.0      Asia  36.088001   739.981106       Low

# %% [markdown]
# ### Filtrowanie danych

# %% [markdown]
# Przy wykorzystaniu operatorów bitowych

# %%
df[ (df.year>1957) & (df.lifeexp>40 )& ~(df.pop_range=='Low') & 
   ((df.continent=='Asia')|(df.continent=='Europe')) ]
# Out:
#          Country  year         pop continent    lifeexp  GDP_per_cap pop_range
# 98    BANGLADESH  1962  56839289.0      Asia  41.216000   686.341554    Medium
# 99    BANGLADESH  1967  62821884.0      Asia  43.452999   721.186086    Medium
# 100   BANGLADESH  1972  70759295.0      Asia  45.251999   630.233627    Medium
# 101   BANGLADESH  1977  80428306.0      Asia  46.923000   659.877232    Medium
# 102   BANGLADESH  1982  93074406.0      Asia  50.008999   676.981866    Medium
# ...          ...   ...         ...       ...        ...          ...       ...
# 1651     VIETNAM  1987  62826491.0      Asia  62.820000   820.799445    Medium
# 1652     VIETNAM  1992  69940728.0      Asia  67.662003   989.023149    Medium
# 1653     VIETNAM  1997  76048996.0      Asia  70.671997  1385.896769    Medium
# 1654     VIETNAM  2002  80908147.0      Asia  73.016998  1764.456677    Medium
# 1655     VIETNAM  2007  85262356.0      Asia  74.249001  2441.576404    Medium
#
# [126 rows x 7 columns]

# %% [markdown]
# Przy wykorzystaniu kwerendy

# %%
df.query("year>1957 and lifeexp>40 and \
         not pop_range=='Low' and continent in ['Europe','Asia'] ")
# Out:
#          Country  year         pop continent    lifeexp  GDP_per_cap pop_range
# 98    BANGLADESH  1962  56839289.0      Asia  41.216000   686.341554    Medium
# 99    BANGLADESH  1967  62821884.0      Asia  43.452999   721.186086    Medium
# 100   BANGLADESH  1972  70759295.0      Asia  45.251999   630.233627    Medium
# 101   BANGLADESH  1977  80428306.0      Asia  46.923000   659.877232    Medium
# 102   BANGLADESH  1982  93074406.0      Asia  50.008999   676.981866    Medium
# ...          ...   ...         ...       ...        ...          ...       ...
# 1651     VIETNAM  1987  62826491.0      Asia  62.820000   820.799445    Medium
# 1652     VIETNAM  1992  69940728.0      Asia  67.662003   989.023149    Medium
# 1653     VIETNAM  1997  76048996.0      Asia  70.671997  1385.896769    Medium
# 1654     VIETNAM  2002  80908147.0      Asia  73.016998  1764.456677    Medium
# 1655     VIETNAM  2007  85262356.0      Asia  74.249001  2441.576404    Medium
#
# [126 rows x 7 columns]

# %% [markdown]
# ### Grupowanie danych

# %%
dfg = df.groupby('continent')

# %% [markdown]
# Zliczenie elementów w poszczególnych grupach

# %%
dfg.count()
# Out:
#            Country  year  pop  lifeexp  GDP_per_cap  pop_range
# continent
# Africa         624   624  624      624          624        624
# Americas       300   300  300      300          300        300
# Asia           396   396  396      396          396        396
# Europe         360   360  360      360          360        360
# Oceania         24    24   24       24           24         24

# %% [markdown]
# Pobranie elementów z danej grupy

# %%
dfg.get_group('Oceania')
# Out:
#           Country  year         pop continent    lifeexp  GDP_per_cap  \
# 60      AUSTRALIA  1952   8691212.0   Oceania  69.120003  10039.59564
# 61      AUSTRALIA  1957   9712569.0   Oceania  70.330002  10949.64959
# 62      AUSTRALIA  1962  10794968.0   Oceania  70.930000  12217.22686
# 63      AUSTRALIA  1967  11872264.0   Oceania  71.099998  14526.12465
# 64      AUSTRALIA  1972  13177000.0   Oceania  71.930000  16788.62948
# 65      AUSTRALIA  1977  14074100.0   Oceania  73.489998  18334.19751
# 66      AUSTRALIA  1982  15184200.0   Oceania  74.739998  19477.00928
# 67      AUSTRALIA  1987  16257249.0   Oceania  76.320000  21888.88903
# 68      AUSTRALIA  1992  17481977.0   Oceania  77.559998  23424.76683
# 69      AUSTRALIA  1997  18565243.0   Oceania  78.830002  26997.93657
# 70      AUSTRALIA  2002  19546792.0   Oceania  80.370003  30687.75473
# 71      AUSTRALIA  2007  20434176.0   Oceania  81.235001  34435.36744
# 1092  NEW ZEALAND  1952   1994794.0   Oceania  69.389999  10556.57566
# 1093  NEW ZEALAND  1957   2229407.0   Oceania  70.260002  12247.39532
# 1094  NEW ZEALAND  1962   2488550.0   Oceania  71.239998  13175.67800
# 1095  NEW ZEALAND  1967   2728150.0   Oceania  71.519997  14463.91893
# 1096  NEW ZEALAND  1972   2929100.0   Oceania  71.889999  16046.03728
# 1097  NEW ZEALAND  1977   3164900.0   Oceania  72.220001  16233.71770
# 1098  NEW ZEALAND  1982   3210650.0   Oceania  73.839996  17632.41040
# 1099  NEW ZEALAND  1987   3317166.0   Oceania  74.320000  19007.19129
# 1100  NEW ZEALAND  1992   3437674.0   Oceania  76.330002  18363.32494
# 1101  NEW ZEALAND  1997   3676187.0   Oceania  77.550003  21050.41377
# 1102  NEW ZEALAND  2002   3908037.0   Oceania  79.110001  23189.80135
# 1103  NEW ZEALAND  2007   4115771.0   Oceania  80.204002  25185.00911
#
#      pop_range
# 60         Low
# 61         Low
# 62         Low
# 63         Low
# 64         Low
# 65         Low
# 66         Low
# 67         Low
# 68         Low
# 69         Low
# 70         Low
# 71         Low
# 1092       Low
# 1093       Low
# 1094       Low
# 1095       Low
# 1096       Low
# 1097       Low
# 1098       Low
# 1099       Low
# 1100       Low
# 1101       Low
# 1102       Low
# 1103       Low

# %% [markdown]
# Wykonanie funkcji agregującej - wariant 1

# %%
dfg["GDP_per_cap"].mean()
# Out:
# continent
# Africa       2193.754578
# Americas     7136.110356
# Asia         7902.150428
# Europe      14469.475533
# Oceania     18621.609223
# Name: GDP_per_cap, dtype: float64

# %% [markdown]
# Wykonanie funkcji agregującej - wariant 2

# %%
dfg["GDP_per_cap"].agg([np.std, np.mean])
# Out:
#                     std          mean
# continent
# Africa      2827.929863   2193.754578
# Americas    6396.764112   7136.110356
# Asia       14045.373112   7902.150428
# Europe      9355.213498  14469.475533
# Oceania     6358.983321  18621.609223

# %% [markdown]
# Wykonanie funkcji agregującej - wariant 3

# %%
dfg.agg({
    "GDP_per_cap" : [np.min, np.max],
    "lifeexp" : [np.mean, np.median]
})
# Out:
#             GDP_per_cap                  lifeexp
#                    amin          amax       mean     median
# continent
# Africa       241.165876   21951.21176  48.865330  47.792000
# Americas    1201.637154   42951.65309  64.658737  67.048004
# Asia         331.000000  113523.13290  60.064903  61.791500
# Europe       973.533195   49357.19017  71.903687  72.240997
# Oceania    10039.595640   34435.36744  74.326210  73.664993

# %% [markdown]
# Pobranie top wartości z każdej grupy dla wartości z zadanej kolumny

# %%
df.sort_values('lifeexp', ascending=False).groupby('continent').first()
# Out:
#              Country  year          pop    lifeexp   GDP_per_cap pop_range
# continent
# Africa       REUNION  2007     798094.0  76.442001   7670.122558       Low
# Americas      CANADA  2007   33390141.0  80.653000  36319.235010       Low
# Asia           JAPAN  2007  127467972.0  82.602997  31656.068060      High
# Europe       ICELAND  2007     301931.0  81.757004  36180.789190       Low
# Oceania    AUSTRALIA  2007   20434176.0  81.235001  34435.367440       Low

# %% [markdown]
# Grupowanie z wykorzystaniem wielu kolumn

# %%
df.groupby(['continent','year']).mean()
# Out:
#                          pop    lifeexp   GDP_per_cap
# continent year
# Africa    1952  4.570010e+06  39.135498   1252.572466
#           1957  5.093033e+06  41.266346   1385.236062
#           1962  5.702247e+06  43.319443   1598.078825
#           1967  6.447875e+06  45.334538   2050.363801
#           1972  7.305376e+06  47.450943   2339.615674
#           1977  8.328097e+06  49.580421   2585.938508
#           1982  9.602857e+06  51.592865   2481.592960
#           1987  1.105450e+07  53.344788   2282.668991
#           1992  1.267464e+07  53.629578   2281.810333
#           1997  1.430448e+07  53.598270   2378.759555
#           2002  1.603315e+07  53.325230   2599.385159
#           2007  1.787576e+07  54.806038   3089.032605
# Americas  1952  1.380610e+07  53.279839   4079.062552
#           1957  1.547816e+07  55.960281   4616.043733
#           1962  1.733081e+07  58.398762   4901.541870
#           1967  1.922986e+07  60.410919   5668.253496
#           1972  2.117537e+07  62.394920   6491.334139
#           1977  2.312271e+07  64.391563   7352.007126
#           1982  2.521164e+07  66.228844   7506.737088
#           1987  2.731016e+07  68.090721   7793.400261
#           1992  2.957096e+07  69.568359   8044.934406
#           1997  3.187602e+07  71.150482   8889.300863
#           2002  3.399091e+07  72.422035   9287.677107
#           2007  3.595485e+07  73.608124  11003.031625
# Asia      1952  4.228356e+07  46.314392   5195.484004
#           1957  4.735699e+07  49.318546   5787.732940
#           1962  5.140476e+07  51.563225   5729.369625
#           1967  5.774736e+07  54.663639   5971.173374
#           1972  6.518098e+07  57.319271   8187.468699
#           1977  7.225799e+07  59.610558   7791.314020
#           1982  7.909502e+07  62.617939   7434.135157
#           1987  8.700669e+07  64.851181   7608.226508
#           1992  9.494825e+07  66.537209   8639.690248
#           1997  1.025238e+08  68.020515   9834.093295
#           2002  1.091455e+08  69.233879  10174.090397
#           2007  1.155138e+08  70.728485  12473.026870
# Europe    1952  1.393736e+07  64.408501   5661.057435
#           1957  1.459635e+07  66.703064   6963.012816
#           1962  1.534517e+07  68.539230   8365.486814
#           1967  1.603930e+07  69.737602  10143.823757
#           1972  1.668784e+07  70.775032  12479.575246
#           1977  1.723882e+07  71.937767  14283.979110
#           1982  1.770890e+07  72.806404  15617.896551
#           1987  1.810314e+07  73.642166  17214.310727
#           1992  1.860476e+07  74.440102  17061.568084
#           1997  1.896480e+07  75.505165  19076.781802
#           2002  1.927413e+07  76.700600  21711.732422
#           2007  1.953662e+07  77.648598  25054.481636
# Oceania   1952  5.343003e+06  69.255005  10298.085650
#           1957  5.970988e+06  70.294998  11598.522455
#           1962  6.641759e+06  71.084999  12696.452430
#           1967  7.300207e+06  71.309998  14495.021790
#           1972  8.053050e+06  71.910004  16417.333380
#           1977  8.619500e+06  72.854996  17283.957605
#           1982  9.197425e+06  74.289993  18554.709840
#           1987  9.787208e+06  75.320000  20448.040160
#           1992  1.045983e+07  76.945000  20894.045885
#           1997  1.112072e+07  78.190002  24024.175170
#           2002  1.172741e+07  79.740005  26938.778040
#           2007  1.227497e+07  80.719498  29810.188275

# %% [markdown]
# ### Deduplikacja danych

# %% [markdown]
# Znajdowanie duplikatów

# %%
df.duplicated().sum() #liczba duplikatów
# Out:
# 0

# %% [markdown]
# Znajdowanie duplikatów na podstawie określonych kolumns

# %%
df.duplicated(subset='Country').sum()
# Out:
# 1562

# %% [markdown]
# Pokaż zduplikowane rekordy

# %%
df[df.duplicated(subset='Country')]
# Out:
#           Country  year         pop continent    lifeexp  GDP_per_cap  \
# 1     AFGHANISTAN  1957   9240934.0      Asia  30.332001   820.853030
# 2     AFGHANISTAN  1962  10267083.0      Asia  31.997000   853.100710
# 3     AFGHANISTAN  1967  11537966.0      Asia  34.020000   836.197138
# 4     AFGHANISTAN  1972  13079460.0      Asia  36.088001   739.981106
# 5     AFGHANISTAN  1977  14880372.0      Asia  38.438000   786.113360
# ...           ...   ...         ...       ...        ...          ...
# 1699     ZIMBABWE  1987   9216418.0    Africa  62.351002   706.157306
# 1700     ZIMBABWE  1992  10704340.0    Africa  60.376999   693.420786
# 1701     ZIMBABWE  1997  11404948.0    Africa  46.808998   792.449960
# 1702     ZIMBABWE  2002  11926563.0    Africa  39.988998   672.038623
# 1703     ZIMBABWE  2007  12311143.0    Africa  43.487000   469.709298
#
#      pop_range
# 1          Low
# 2          Low
# 3          Low
# 4          Low
# 5          Low
# ...        ...
# 1699       Low
# 1700       Low
# 1701       Low
# 1702       Low
# 1703       Low
#
# [1562 rows x 7 columns]

# %% [markdown]
# Usuń duplikaty na podstawie kryterium kolumn, pozostaw tylko ostanie wystąpienie

# %%
df.drop_duplicates(subset='Country', keep='last') # parametr keep określa strategię usuwania
# Out:
#                  Country  year         pop continent    lifeexp   GDP_per_cap  \
# 11           AFGHANISTAN  2007  31889923.0      Asia  43.827999    974.580338
# 23               ALBANIA  2007   3600523.0    Europe  76.422997   5937.029526
# 35               ALGERIA  2007  33333216.0    Africa  72.301003   6223.367465
# 47                ANGOLA  2007  12420476.0    Africa  42.730999   4797.231267
# 59             ARGENTINA  2007  40301927.0  Americas  75.320000  12779.379640
# ...                  ...   ...         ...       ...        ...           ...
# 1655             VIETNAM  2007  85262356.0      Asia  74.249001   2441.576404
# 1667  WEST BANK AND GAZA  2007   4018332.0      Asia  73.421997   3025.349798
# 1679          YEMEN REP.  2007  22211743.0      Asia  62.698002   2280.769906
# 1691              ZAMBIA  2007  11746035.0    Africa  42.383999   1271.211593
# 1703            ZIMBABWE  2007  12311143.0    Africa  43.487000    469.709298
#
#      pop_range
# 11         Low
# 23         Low
# 35         Low
# 47         Low
# 59         Low
# ...        ...
# 1655    Medium
# 1667       Low
# 1679       Low
# 1691       Low
# 1703       Low
#
# [142 rows x 7 columns]

# %% [markdown]
# ### Budowanie rankingu

# %%
df_tmp = df.query("year==2007")
df_tmp["ranking"] = df_tmp.loc[:, "lifeexp"].rank(ascending=False) # ascending=False - większa wartość = wyższa pozycja
df_tmp.sort_values('ranking')
# Out:
#               Country  year          pop continent    lifeexp   GDP_per_cap  \
# 803             JAPAN  2007  127467972.0      Asia  82.602997  31656.068060
# 671   HONG KONG CHINA  2007    6980412.0      Asia  82.208000  39724.978670
# 695           ICELAND  2007     301931.0    Europe  81.757004  36180.789190
# 1487      SWITZERLAND  2007    7554661.0    Europe  81.700996  37506.419070
# 71          AUSTRALIA  2007   20434176.0   Oceania  81.235001  34435.367440
# ...               ...   ...          ...       ...        ...           ...
# 887           LESOTHO  2007    2012649.0    Africa  42.591999   1569.331442
# 1355     SIERRA LEONE  2007    6144562.0    Africa  42.568001    862.540756
# 1691           ZAMBIA  2007   11746035.0    Africa  42.383999   1271.211593
# 1043       MOZAMBIQUE  2007   19951656.0    Africa  42.082001    823.685621
# 1463        SWAZILAND  2007    1133066.0    Africa  39.612999   4513.480643
#
#      pop_range  ranking
# 803       High      1.0
# 671        Low      2.0
# 695        Low      3.0
# 1487       Low      4.0
# 71         Low      5.0
# ...        ...      ...
# 887        Low    138.0
# 1355       Low    139.0
# 1691       Low    140.0
# 1043       Low    141.0
# 1463       Low    142.0
#
# [142 rows x 8 columns]

# %% [markdown]
# ### Obsługa wartości brakujących (missing values)

# %%
df_tmp = df.sample(n=15, random_state=42, ignore_index=True)

np.random.seed(1) # ustawienie ziarna pseudolosowości

arr = np.random.randint(0, len(df_tmp), 5) # wylosuj 5 pseudolosowych wartości
df_tmp.loc[ arr , "GDP_per_cap" ] = np.NaN # i przypisz w kolumnie GDP_per_cap wartość NaN

arr = np.random.randint(0, len(df_tmp), 5) # wylosuj 5 pseudolosowych wartości
df_tmp.loc[ arr , "pop" ] = np.NaN # # i przypisz w kolumnie GDP_per_cap wartość NaN

df_tmp[-1:] = (np.NaN,)*7 # ostatni wiersz zawierający wyłącznie NaN
df_tmp
# Out:
#                      Country    year         pop continent    lifeexp  \
# 0                    MYANMAR  1962.0         NaN      Asia  45.108002
# 1                    IRELAND  1957.0         NaN    Europe  68.900002
# 2                    JAMAICA  1977.0   2156814.0  Americas  70.110001
# 3              COTE D'IVOIRE  1987.0  10761098.0    Africa  54.654999
# 4                    MOROCCO  1997.0  28529501.0    Africa  67.660004
# 5                    VIETNAM  1972.0         NaN      Asia  50.254002
# 6   CENTRAL AFRICAN REPUBLIC  1987.0   2840009.0    Africa  50.485001
# 7                     TAIWAN  1997.0  21628605.0      Asia  75.250000
# 8                   ETHIOPIA  2002.0  67946797.0    Africa  50.724998
# 9                     POLAND  1977.0  34621254.0    Europe  70.669998
# 10                   ALBANIA  2007.0   3600523.0    Europe  76.422997
# 11                   GERMANY  1982.0         NaN    Europe  73.800003
# 12                   BELGIUM  1987.0   9870200.0    Europe  75.349998
# 13                MADAGASCAR  1962.0   5703324.0    Africa  40.848000
# 14                       NaN     NaN         NaN       NaN        NaN
#
#      GDP_per_cap pop_range
# 0     388.000000       Low
# 1    5599.077872       Low
# 2    6650.195573       Low
# 3    2156.956069       Low
# 4    2982.101858       Low
# 5            NaN       Low
# 6     844.876350       Low
# 7   20206.820980       Low
# 8            NaN    Medium
# 9            NaN       Low
# 10   5937.029526       Low
# 11           NaN    Medium
# 12           NaN       Low
# 13   1643.387110       Low
# 14           NaN       NaN

# %% [markdown]
# Znalazienie ilości NaN w DataFrame

# %%
df_tmp.isna().sum()
# Out:
# Country        1
# year           1
# pop            5
# continent      1
# lifeexp        1
# GDP_per_cap    6
# pop_range      1
# dtype: int64

# %% [markdown]
# Usunięcie wierszy zawierających przynajmniej jedną wartość NaN

# %%
df_tmp.dropna(axis=0, how='any')
# Out:
#                      Country    year         pop continent    lifeexp  \
# 2                    JAMAICA  1977.0   2156814.0  Americas  70.110001
# 3              COTE D'IVOIRE  1987.0  10761098.0    Africa  54.654999
# 4                    MOROCCO  1997.0  28529501.0    Africa  67.660004
# 6   CENTRAL AFRICAN REPUBLIC  1987.0   2840009.0    Africa  50.485001
# 7                     TAIWAN  1997.0  21628605.0      Asia  75.250000
# 10                   ALBANIA  2007.0   3600523.0    Europe  76.422997
# 13                MADAGASCAR  1962.0   5703324.0    Africa  40.848000
#
#      GDP_per_cap pop_range
# 2    6650.195573       Low
# 3    2156.956069       Low
# 4    2982.101858       Low
# 6     844.876350       Low
# 7   20206.820980       Low
# 10   5937.029526       Low
# 13   1643.387110       Low

# %% [markdown]
# Usunięcie wierszy zawierających wszystkie wartości NaN

# %%
df_tmp.dropna(axis=0, how='all')
# Out:
#                      Country    year         pop continent    lifeexp  \
# 0                    MYANMAR  1962.0         NaN      Asia  45.108002
# 1                    IRELAND  1957.0         NaN    Europe  68.900002
# 2                    JAMAICA  1977.0   2156814.0  Americas  70.110001
# 3              COTE D'IVOIRE  1987.0  10761098.0    Africa  54.654999
# 4                    MOROCCO  1997.0  28529501.0    Africa  67.660004
# 5                    VIETNAM  1972.0         NaN      Asia  50.254002
# 6   CENTRAL AFRICAN REPUBLIC  1987.0   2840009.0    Africa  50.485001
# 7                     TAIWAN  1997.0  21628605.0      Asia  75.250000
# 8                   ETHIOPIA  2002.0  67946797.0    Africa  50.724998
# 9                     POLAND  1977.0  34621254.0    Europe  70.669998
# 10                   ALBANIA  2007.0   3600523.0    Europe  76.422997
# 11                   GERMANY  1982.0         NaN    Europe  73.800003
# 12                   BELGIUM  1987.0   9870200.0    Europe  75.349998
# 13                MADAGASCAR  1962.0   5703324.0    Africa  40.848000
#
#      GDP_per_cap pop_range
# 0     388.000000       Low
# 1    5599.077872       Low
# 2    6650.195573       Low
# 3    2156.956069       Low
# 4    2982.101858       Low
# 5            NaN       Low
# 6     844.876350       Low
# 7   20206.820980       Low
# 8            NaN    Medium
# 9            NaN       Low
# 10   5937.029526       Low
# 11           NaN    Medium
# 12           NaN       Low
# 13   1643.387110       Low

# %% [markdown]
# Usunięcie kolumn zawierających przynajmniej jedną wartość NaN

# %%
df_tmp = df_tmp.iloc[:-1,]
df_tmp.dropna(axis=1, how='any')
# Out:
#                      Country    year continent    lifeexp pop_range
# 0                    MYANMAR  1962.0      Asia  45.108002       Low
# 1                    IRELAND  1957.0    Europe  68.900002       Low
# 2                    JAMAICA  1977.0  Americas  70.110001       Low
# 3              COTE D'IVOIRE  1987.0    Africa  54.654999       Low
# 4                    MOROCCO  1997.0    Africa  67.660004       Low
# 5                    VIETNAM  1972.0      Asia  50.254002       Low
# 6   CENTRAL AFRICAN REPUBLIC  1987.0    Africa  50.485001       Low
# 7                     TAIWAN  1997.0      Asia  75.250000       Low
# 8                   ETHIOPIA  2002.0    Africa  50.724998    Medium
# 9                     POLAND  1977.0    Europe  70.669998       Low
# 10                   ALBANIA  2007.0    Europe  76.422997       Low
# 11                   GERMANY  1982.0    Europe  73.800003    Medium
# 12                   BELGIUM  1987.0    Europe  75.349998       Low
# 13                MADAGASCAR  1962.0    Africa  40.848000       Low

# %% [markdown]
# Zastąpienie wartości NaN w kolumnie "pop" wartością zero

# %%
df_tmp["pop"] = df_tmp["pop"].fillna(0)
df_tmp
# Out:
#                      Country    year         pop continent    lifeexp  \
# 0                    MYANMAR  1962.0         0.0      Asia  45.108002
# 1                    IRELAND  1957.0         0.0    Europe  68.900002
# 2                    JAMAICA  1977.0   2156814.0  Americas  70.110001
# 3              COTE D'IVOIRE  1987.0  10761098.0    Africa  54.654999
# 4                    MOROCCO  1997.0  28529501.0    Africa  67.660004
# 5                    VIETNAM  1972.0         0.0      Asia  50.254002
# 6   CENTRAL AFRICAN REPUBLIC  1987.0   2840009.0    Africa  50.485001
# 7                     TAIWAN  1997.0  21628605.0      Asia  75.250000
# 8                   ETHIOPIA  2002.0  67946797.0    Africa  50.724998
# 9                     POLAND  1977.0  34621254.0    Europe  70.669998
# 10                   ALBANIA  2007.0   3600523.0    Europe  76.422997
# 11                   GERMANY  1982.0         0.0    Europe  73.800003
# 12                   BELGIUM  1987.0   9870200.0    Europe  75.349998
# 13                MADAGASCAR  1962.0   5703324.0    Africa  40.848000
#
#      GDP_per_cap pop_range
# 0     388.000000       Low
# 1    5599.077872       Low
# 2    6650.195573       Low
# 3    2156.956069       Low
# 4    2982.101858       Low
# 5            NaN       Low
# 6     844.876350       Low
# 7   20206.820980       Low
# 8            NaN    Medium
# 9            NaN       Low
# 10   5937.029526       Low
# 11           NaN    Medium
# 12           NaN       Low
# 13   1643.387110       Low

# %% [markdown]
# Zastąpienie wartości NaN w kolumnie "GDP_per_cap" ostatnią poprzednią wartością nie będącą NaN

# %%
df_tmp["GDP_per_cap"] = df_tmp["GDP_per_cap"].fillna(method='ffill')
df_tmp
# Out:
#                      Country    year         pop continent    lifeexp  \
# 0                    MYANMAR  1962.0         0.0      Asia  45.108002
# 1                    IRELAND  1957.0         0.0    Europe  68.900002
# 2                    JAMAICA  1977.0   2156814.0  Americas  70.110001
# 3              COTE D'IVOIRE  1987.0  10761098.0    Africa  54.654999
# 4                    MOROCCO  1997.0  28529501.0    Africa  67.660004
# 5                    VIETNAM  1972.0         0.0      Asia  50.254002
# 6   CENTRAL AFRICAN REPUBLIC  1987.0   2840009.0    Africa  50.485001
# 7                     TAIWAN  1997.0  21628605.0      Asia  75.250000
# 8                   ETHIOPIA  2002.0  67946797.0    Africa  50.724998
# 9                     POLAND  1977.0  34621254.0    Europe  70.669998
# 10                   ALBANIA  2007.0   3600523.0    Europe  76.422997
# 11                   GERMANY  1982.0         0.0    Europe  73.800003
# 12                   BELGIUM  1987.0   9870200.0    Europe  75.349998
# 13                MADAGASCAR  1962.0   5703324.0    Africa  40.848000
#
#      GDP_per_cap pop_range
# 0     388.000000       Low
# 1    5599.077872       Low
# 2    6650.195573       Low
# 3    2156.956069       Low
# 4    2982.101858       Low
# 5    2982.101858       Low
# 6     844.876350       Low
# 7   20206.820980       Low
# 8   20206.820980    Medium
# 9   20206.820980       Low
# 10   5937.029526       Low
# 11   5937.029526    Medium
# 12   5937.029526       Low
# 13   1643.387110       Low

# %% [markdown]
# ### Piwot obiektu DataFrame

# %%
pd.pivot_table(data=df, index="continent", columns="year", values="GDP_per_cap")
# Out:
# year               1952          1957          1962          1967  \
# continent
# Africa      1252.572466   1385.236062   1598.078825   2050.363801
# Americas    4079.062552   4616.043733   4901.541870   5668.253496
# Asia        5195.484004   5787.732940   5729.369625   5971.173374
# Europe      5661.057435   6963.012816   8365.486814  10143.823757
# Oceania    10298.085650  11598.522455  12696.452430  14495.021790
#
# year               1972          1977          1982          1987  \
# continent
# Africa      2339.615674   2585.938508   2481.592960   2282.668991
# Americas    6491.334139   7352.007126   7506.737088   7793.400261
# Asia        8187.468699   7791.314020   7434.135157   7608.226508
# Europe     12479.575246  14283.979110  15617.896551  17214.310727
# Oceania    16417.333380  17283.957605  18554.709840  20448.040160
#
# year               1992          1997          2002          2007
# continent
# Africa      2281.810333   2378.759555   2599.385159   3089.032605
# Americas    8044.934406   8889.300863   9287.677107  11003.031625
# Asia        8639.690248   9834.093295  10174.090397  12473.026870
# Europe     17061.568084  19076.781802  21711.732422  25054.481636
# Oceania    20894.045885  24024.175170  26938.778040  29810.188275

# %%
pd.pivot_table(data=df, index="continent", columns="year", aggfunc={
    "GDP_per_cap" : [np.median, np.max]
})
# Out:
#              GDP_per_cap                                            \
#                     amax
# year                1952           1957          1962         1967
# continent
# Africa       4725.295531    5487.104219   6757.030816  18772.75169
# Americas    13990.482080   14847.127120  16173.145860  19530.36557
# Asia       108382.352900  113523.132900  95458.111760  80894.88326
# Europe      14734.232750   17909.489730  20431.092700  22966.14432
# Oceania     10556.575660   12247.395320  13175.678000  14526.12465
#
#                                                                              \
#
# year               1972         1977         1982         1987         1992
# continent
# Africa      21011.49721  21951.21176  17364.27538  11864.40844  13522.15752
# Americas    21806.03594  24072.63213  25009.55914  29884.35041  32003.93224
# Asia       109347.86700  59265.47714  33693.17525  28118.42998  34932.91959
# Europe      27195.11304  26982.29052  28397.71512  31540.97480  33965.66115
# Oceania     16788.62948  18334.19751  19477.00928  21888.88903  23424.76683
#
#                         ...                                            \
#                         ...        median
# year              1997  ...          1962          1967          1972
# continent               ...
# Africa     14722.84188  ...   1133.783678   1210.376379   1443.372508
# Americas   35767.43303  ...   4086.114078   4643.393534   5305.445256
# Asia       40300.61996  ...   1649.552153   2029.228142   2571.423014
# Europe     41283.16433  ...   7515.733737   9366.067033  12326.379990
# Oceania    26997.93657  ...  12696.452430  14495.021790  16417.333380
#
#                                                                    \
#
# year               1977          1982          1987          1992
# continent
# Africa      1399.638836   1323.728306   1219.585563   1161.631357
# Americas    6281.290855   6434.501797   6360.943444   6618.743050
# Asia        3195.484582   4106.525293   4106.492315   3726.063507
# Europe     14225.754515  15322.824720  16215.485895  17550.155945
# Oceania    17283.957605  18554.709840  20448.040160  20894.045885
#
#
#
# year               1997          2002          2007
# continent
# Africa      1179.883114   1215.683217   1452.267078
# Americas    7113.692252   6994.774861   8948.102923
# Asia        3645.379572   4090.925331   4471.061906
# Europe     19596.498550  23674.863230  28054.065790
# Oceania    24024.175170  26938.778040  29810.188275
#
# [5 rows x 24 columns]

# %% [markdown]
# ### Przesuwanie danych (data shifting)

# %%
df_tmp = df.query("Country=='POLAND'").sort_values('year')
df_tmp
# Out:
#      Country  year         pop continent    lifeexp   GDP_per_cap pop_range
# 1224  POLAND  1952  25730551.0    Europe  61.310001   4029.329699       Low
# 1225  POLAND  1957  28235346.0    Europe  65.769997   4734.253019       Low
# 1226  POLAND  1962  30329617.0    Europe  67.639999   5338.752143       Low
# 1227  POLAND  1967  31785378.0    Europe  69.610001   6557.152776       Low
# 1228  POLAND  1972  33039545.0    Europe  70.849998   8006.506993       Low
# 1229  POLAND  1977  34621254.0    Europe  70.669998   9508.141454       Low
# 1230  POLAND  1982  36227381.0    Europe  71.320000   8451.531004       Low
# 1231  POLAND  1987  37740710.0    Europe  70.980003   9082.351172       Low
# 1232  POLAND  1992  38370697.0    Europe  70.989998   7738.881247       Low
# 1233  POLAND  1997  38654957.0    Europe  72.750000  10159.583680       Low
# 1234  POLAND  2002  38625976.0    Europe  74.669998  12002.239080       Low
# 1235  POLAND  2007  38518241.0    Europe  75.563004  15389.924680       Low

# %% [markdown]
# Porównanie liczby ludności - kolumna 'pop' - rok do roku
#
# <a href='https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.shift.html'>https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.shift.html</a>

# %%
df_tmp["pop_change"] = df_tmp["pop"] - df_tmp["pop"].shift(1)
df_tmp
# Out:
#      Country  year         pop continent    lifeexp   GDP_per_cap pop_range  \
# 1224  POLAND  1952  25730551.0    Europe  61.310001   4029.329699       Low
# 1225  POLAND  1957  28235346.0    Europe  65.769997   4734.253019       Low
# 1226  POLAND  1962  30329617.0    Europe  67.639999   5338.752143       Low
# 1227  POLAND  1967  31785378.0    Europe  69.610001   6557.152776       Low
# 1228  POLAND  1972  33039545.0    Europe  70.849998   8006.506993       Low
# 1229  POLAND  1977  34621254.0    Europe  70.669998   9508.141454       Low
# 1230  POLAND  1982  36227381.0    Europe  71.320000   8451.531004       Low
# 1231  POLAND  1987  37740710.0    Europe  70.980003   9082.351172       Low
# 1232  POLAND  1992  38370697.0    Europe  70.989998   7738.881247       Low
# 1233  POLAND  1997  38654957.0    Europe  72.750000  10159.583680       Low
# 1234  POLAND  2002  38625976.0    Europe  74.669998  12002.239080       Low
# 1235  POLAND  2007  38518241.0    Europe  75.563004  15389.924680       Low
#
#       pop_change
# 1224         NaN
# 1225   2504795.0
# 1226   2094271.0
# 1227   1455761.0
# 1228   1254167.0
# 1229   1581709.0
# 1230   1606127.0
# 1231   1513329.0
# 1232    629987.0
# 1233    284260.0
# 1234    -28981.0
# 1235   -107735.0

# %% [markdown]
# ### Łączenie obiektów DataFrame

# %% [markdown]
# Łączenie wierszami

# %%
df1 = df.iloc[:10]  #pobierz pierwsze 10 wierszy
df2 = df.iloc[-10:] #pobierz ostatnie 10 wierszy
df1.append(df2, ignore_index=True)
# Out:
#         Country  year         pop continent    lifeexp  GDP_per_cap pop_range
# 0   AFGHANISTAN  1952   8425333.0      Asia  28.801001   779.445314       Low
# 1   AFGHANISTAN  1957   9240934.0      Asia  30.332001   820.853030       Low
# 2   AFGHANISTAN  1962  10267083.0      Asia  31.997000   853.100710       Low
# 3   AFGHANISTAN  1967  11537966.0      Asia  34.020000   836.197138       Low
# 4   AFGHANISTAN  1972  13079460.0      Asia  36.088001   739.981106       Low
# 5   AFGHANISTAN  1977  14880372.0      Asia  38.438000   786.113360       Low
# 6   AFGHANISTAN  1982  12881816.0      Asia  39.854000   978.011439       Low
# 7   AFGHANISTAN  1987  13867957.0      Asia  40.821999   852.395945       Low
# 8   AFGHANISTAN  1992  16317921.0      Asia  41.674000   649.341395       Low
# 9   AFGHANISTAN  1997  22227415.0      Asia  41.763000   635.341351       Low
# 10     ZIMBABWE  1962   4277736.0    Africa  52.358002   527.272182       Low
# 11     ZIMBABWE  1967   4995432.0    Africa  53.994999   569.795071       Low
# 12     ZIMBABWE  1972   5861135.0    Africa  55.634998   799.362176       Low
# 13     ZIMBABWE  1977   6642107.0    Africa  57.674000   685.587682       Low
# 14     ZIMBABWE  1982   7636524.0    Africa  60.362999   788.855041       Low
# 15     ZIMBABWE  1987   9216418.0    Africa  62.351002   706.157306       Low
# 16     ZIMBABWE  1992  10704340.0    Africa  60.376999   693.420786       Low
# 17     ZIMBABWE  1997  11404948.0    Africa  46.808998   792.449960       Low
# 18     ZIMBABWE  2002  11926563.0    Africa  39.988998   672.038623       Low
# 19     ZIMBABWE  2007  12311143.0    Africa  43.487000   469.709298       Low

# %% [markdown]
# Łączenie wierszami z wykorzystaniem pd.concat()

# %%
pd.concat([df1, df2], axis=0, ignore_index=True)
# Out:
#         Country  year         pop continent    lifeexp  GDP_per_cap pop_range
# 0   AFGHANISTAN  1952   8425333.0      Asia  28.801001   779.445314       Low
# 1   AFGHANISTAN  1957   9240934.0      Asia  30.332001   820.853030       Low
# 2   AFGHANISTAN  1962  10267083.0      Asia  31.997000   853.100710       Low
# 3   AFGHANISTAN  1967  11537966.0      Asia  34.020000   836.197138       Low
# 4   AFGHANISTAN  1972  13079460.0      Asia  36.088001   739.981106       Low
# 5   AFGHANISTAN  1977  14880372.0      Asia  38.438000   786.113360       Low
# 6   AFGHANISTAN  1982  12881816.0      Asia  39.854000   978.011439       Low
# 7   AFGHANISTAN  1987  13867957.0      Asia  40.821999   852.395945       Low
# 8   AFGHANISTAN  1992  16317921.0      Asia  41.674000   649.341395       Low
# 9   AFGHANISTAN  1997  22227415.0      Asia  41.763000   635.341351       Low
# 10     ZIMBABWE  1962   4277736.0    Africa  52.358002   527.272182       Low
# 11     ZIMBABWE  1967   4995432.0    Africa  53.994999   569.795071       Low
# 12     ZIMBABWE  1972   5861135.0    Africa  55.634998   799.362176       Low
# 13     ZIMBABWE  1977   6642107.0    Africa  57.674000   685.587682       Low
# 14     ZIMBABWE  1982   7636524.0    Africa  60.362999   788.855041       Low
# 15     ZIMBABWE  1987   9216418.0    Africa  62.351002   706.157306       Low
# 16     ZIMBABWE  1992  10704340.0    Africa  60.376999   693.420786       Low
# 17     ZIMBABWE  1997  11404948.0    Africa  46.808998   792.449960       Low
# 18     ZIMBABWE  2002  11926563.0    Africa  39.988998   672.038623       Low
# 19     ZIMBABWE  2007  12311143.0    Africa  43.487000   469.709298       Low

# %% [markdown]
# Łączenie kolumnami z wykorzystaniem pd.concat()

# %%
df1 = df.iloc[:10, :3] # pobierz pierwsze 10 wierszy i pierwsze 3 kolumny
df2 = df.iloc[:10, -3:] # pobierz ostatnie 10 wierszy i ostatnie 3 kolumny
pd.concat([df1, df2], axis=1) # "centrowanie" wierszy odbywa się na podstawie wartości indeksu
# Out:
#        Country  year         pop    lifeexp  GDP_per_cap pop_range
# 0  AFGHANISTAN  1952   8425333.0  28.801001   779.445314       Low
# 1  AFGHANISTAN  1957   9240934.0  30.332001   820.853030       Low
# 2  AFGHANISTAN  1962  10267083.0  31.997000   853.100710       Low
# 3  AFGHANISTAN  1967  11537966.0  34.020000   836.197138       Low
# 4  AFGHANISTAN  1972  13079460.0  36.088001   739.981106       Low
# 5  AFGHANISTAN  1977  14880372.0  38.438000   786.113360       Low
# 6  AFGHANISTAN  1982  12881816.0  39.854000   978.011439       Low
# 7  AFGHANISTAN  1987  13867957.0  40.821999   852.395945       Low
# 8  AFGHANISTAN  1992  16317921.0  41.674000   649.341395       Low
# 9  AFGHANISTAN  1997  22227415.0  41.763000   635.341351       Low

# %% [markdown]
# ### Merge'owanie obiektów DataFrame

# %%
df1 = pd.DataFrame({
    "ID1" : range(1,14,2),
    "value1" : ['A','B','C','D','E','F','G']
})
df1
# Out:
#    ID1 value1
# 0    1      A
# 1    3      B
# 2    5      C
# 3    7      D
# 4    9      E
# 5   11      F
# 6   13      G

# %%
df2 = pd.DataFrame({
    "ID2" : range(1,8),
    "value2" : ['A','B','C','D','E','F','G']
})
df2
# Out:
#    ID2 value2
# 0    1      A
# 1    2      B
# 2    3      C
# 3    4      D
# 4    5      E
# 5    6      F
# 6    7      G

# %% [markdown]
# Intersekcja zbiorów

# %%
pd.merge(df1, df2, left_on='ID1', right_on='ID2', how='inner')
# Out:
#    ID1 value1  ID2 value2
# 0    1      A    1      A
# 1    3      B    3      C
# 2    5      C    5      E
# 3    7      D    7      G

# %% [markdown]
# Suma zbiorów

# %%
pd.merge(df1, df2, left_on='ID1', right_on='ID2', how='outer')
# Out:
#     ID1 value1  ID2 value2
# 0   1.0      A  1.0      A
# 1   3.0      B  3.0      C
# 2   5.0      C  5.0      E
# 3   7.0      D  7.0      G
# 4   9.0      E  NaN    NaN
# 5  11.0      F  NaN    NaN
# 6  13.0      G  NaN    NaN
# 7   NaN    NaN  2.0      B
# 8   NaN    NaN  4.0      D
# 9   NaN    NaN  6.0      F

# %% [markdown]
# Złączenie lewostronne

# %%
pd.merge(df1, df2, left_on='ID1', right_on='ID2', how='left', indicator=True) # left join
# Out:
#    ID1 value1  ID2 value2     _merge
# 0    1      A  1.0      A       both
# 1    3      B  3.0      C       both
# 2    5      C  5.0      E       both
# 3    7      D  7.0      G       both
# 4    9      E  NaN    NaN  left_only
# 5   11      F  NaN    NaN  left_only
# 6   13      G  NaN    NaN  left_only

# %% [markdown]
# Złączenie prawostronne

# %%
pd.merge(df1, df2, left_on='ID1', right_on='ID2', how='right', indicator=True) # right join
# Out:
#    ID1 value1  ID2 value2      _merge
# 0  1.0      A    1      A        both
# 1  NaN    NaN    2      B  right_only
# 2  3.0      B    3      C        both
# 3  NaN    NaN    4      D  right_only
# 4  5.0      C    5      E        both
# 5  NaN    NaN    6      F  right_only
# 6  7.0      D    7      G        both

# %% [markdown]
# ### Zapisz danych z DataFrame do pliku płaskiego

# %%
df.to_csv("filename.csv", index_label="MyIndex", sep=";", decimal=",")
